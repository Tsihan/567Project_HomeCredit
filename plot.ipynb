# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据定义
models = ['Light BGM', 'CatBoost', 'Extra Tree', 'Logistic Regression', 'Random Forest', 'Ridge Regression', 
          'Simple Avg', 'XG Boost', 'Simple Stacking']
train_scores = [0.764122917660593, 0.6799308242093993, 0.6515238489771662, 0.5587160168363116, 0.6744254636303879, 
                0.7084293961738621, 0.746803514436637, 0.7345030302159751, 0.7639836961958666]
valid_scores = [0.7512157223309048, 0.6806821668036167, 0.6570136693501651, 0.5585915521426285, 0.6774176542719132,
                0.706345597933946, 0.7403208455952458, 0.7313456972612628, 0.7553796054166325]
test_scores = [0.7483072129459662, 0.6780545675251102, 0.6511893053529092, 0.5641245625441034, 0.6703914538778727,
               0.7009017609825624, 0.7354131242205908, 0.7275824739379769, 0.748420223608882]

# 根据测试集分数排序
sorted_indices = np.argsort(test_scores)
sorted_models = [models[i] for i in sorted_indices]
sorted_train_scores = [train_scores[i] for i in sorted_indices]
sorted_valid_scores = [valid_scores[i] for i in sorted_indices]
sorted_test_scores = [test_scores[i] for i in sorted_indices]

# 创建图表
fig, ax = plt.subplots(figsize=(14, 8))
x_sorted = np.arange(len(sorted_models))  # 标签位置
width = 0.25  # 条形的宽度

# 创建条形图
rects1 = ax.bar(x_sorted - width, sorted_train_scores, width, label='Train')
rects2 = ax.bar(x_sorted, sorted_valid_scores, width, label='Valid')
rects3 = ax.bar(x_sorted + width, sorted_test_scores, width, label='Test')

# 设置标签、标题和自定义的x轴标签等
ax.set_xlabel('Models')
ax.set_ylabel('AUC Scores')
ax.set_title('AUC Scores by Model')
ax.set_xticks(x_sorted)
ax.set_xticklabels(sorted_models)
ax.legend()

# 在条形图上显示两位小数的数值
ax.bar_label(rects1, padding=3, fmt='%.4f', rotation=45)
ax.bar_label(rects2, padding=3, fmt='%.4f', rotation=45)
ax.bar_label(rects3, padding=3, fmt='%.4f', rotation=45)

fig.tight_layout()

plt.show()

# Stability Scores data
models_stability = ['Light BGM', 'CatBoost', 'Extra Tree', 'Logistic Regression', 'Random Forest', 'Ridge Regression', 
                    'Simple Avg', 'XG Boost', 'Simple Stacking']
train_stability_scores = [0.4976648127691175, 0.3307653566865152, 0.2729033858933445, 0.007337607702594742, 0.3218388023693258, 
                          0.3816491799692487, 0.4626146129239631, 0.44109107784861706, 0.49714354077600303]
valid_stability_scores = [0.4726726686264489, 0.3238845995036411, 0.268090072423159, 0.06136132378936784, 0.3183529208407528,
                          0.37944570177837267, 0.45074169078782467, 0.4332443486564887, 0.48075094467694374]
test_stability_scores = [0.4583643686935092, 0.31374938182470047, 0.263899413156609, 0.013988781151253363, 0.2989112512960005,
                         0.35691865798937517, 0.42950723805694435, 0.41835056851492414, 0.459001310443568]

# Sorting by test stability scores
stability_sorted_indices = np.argsort(test_stability_scores)
stability_sorted_models = [models_stability[i] for i in stability_sorted_indices]
stability_sorted_train_scores = [train_stability_scores[i] for i in stability_sorted_indices]
stability_sorted_valid_scores = [valid_stability_scores[i] for i in stability_sorted_indices]
stability_sorted_test_scores = [test_stability_scores[i] for i in stability_sorted_indices]

# Create stability score plot
fig, ax = plt.subplots(figsize=(14, 8))
x_stability_sorted = np.arange(len(stability_sorted_models))  # the label locations

# Creating bars for stability scores
rects1 = ax.bar(x_stability_sorted - width, stability_sorted_train_scores, width, label='Train')
rects2 = ax.bar(x_stability_sorted, stability_sorted_valid_scores, width, label='Valid')
rects3 = ax.bar(x_stability_sorted + width, stability_sorted_test_scores, width, label='Test')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Models')
ax.set_ylabel('Stability Scores')
ax.set_title('Stability Scores by Model')
ax.set_xticks(x_stability_sorted)
ax.set_xticklabels(stability_sorted_models)
ax.legend()

# Setting bar labels with two decimal places
ax.bar_label(rects1, padding=3, fmt='%.4f', rotation=45)
ax.bar_label(rects2, padding=3, fmt='%.4f', rotation=45)
ax.bar_label(rects3, padding=3, fmt='%.4f', rotation=45)

fig.tight_layout()

plt.show()

# %%
# Re-importing necessary libraries and re-defining the data and code since the code execution state was reset.
import matplotlib.pyplot as plt
import numpy as np

# Stability Scores data redefinition
models_stability = ['CatBoost', 'Extra Tree', 'Logistic Regression', 'Random Forest', 'Ridge Regression', 
                    'Simple Avg', 'XG Boost', 'Simple Stacking']
train_stability_scores = [0.3307653566865152, 0.2729033858933445, 0.007337607702594742, 0.3218388023693258, 
                          0.3816491799692487, 0.4626146129239631, 0.44109107784861706, 0.49714354077600303]
valid_stability_scores = [0.3238845995036411, 0.268090072423159, 0.06136132378936784, 0.3183529208407528,
                          0.37944570177837267, 0.45074169078782467, 0.4332443486564887, 0.48075094467694374]
test_stability_scores = [0.31374938182470047, 0.263899413156609, 0.013988781151253363, 0.2989112512960005,
                         0.35691865798937517, 0.42950723805694435, 0.41835056851492414, 0.459001310443568]

# Sorting by test stability scores
stability_sorted_indices = np.argsort(test_stability_scores)
stability_sorted_models = [models_stability[i] for i in stability_sorted_indices]
stability_sorted_train_scores = [train_stability_scores[i] for i in stability_sorted_indices]
stability_sorted_valid_scores = [valid_stability_scores[i] for i in stability_sorted_indices]
stability_sorted_test_scores = [test_stability_scores[i] for i in stability_sorted_indices]

# Plot creation with adjusted label rotation and decimal places for better clarity
fig, ax = plt.subplots(figsize=(14, 8))
x_stability_sorted = np.arange(len(stability_sorted_models))  # the label locations
width = 0.25  # the width of the bars

# Creating bars for stability scores
rects1 = ax.bar(x_stability_sorted - width, stability_sorted_train_scores, width, label='Train')
rects2 = ax.bar(x_stability_sorted, stability_sorted_valid_scores, width, label='Valid')
rects3 = ax.bar(x_stability_sorted + width, stability_sorted_test_scores, width, label='Test')

# Add text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Models')
ax.set_ylabel('Stability Scores')
ax.set_title('Stability Scores by Model and Dataset (Sorted by Test Scores)')
ax.set_xticks(x_stability_sorted)
ax.set_xticklabels(stability_sorted_models, rotation=45)
ax.legend()

# Setting bar labels with four decimal places and rotated 45 degrees for better visibility
ax.bar_label(rects1, padding=3, fmt='%.4f', rotation=45)
ax.bar_label(rects2, padding=3, fmt='%.4f', rotation=45)
ax.bar_label(rects3, padding=3, fmt='%.4f', rotation=45)

fig.tight_layout()

plt.show()
